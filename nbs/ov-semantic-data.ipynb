# %%
# %load_ext autoreload
# %autoreload 2

import os
from skimage import color

import numpy as np
import matplotlib.pyplot as plt

DATA_DIR = '/home/cem/Desktop/ov-workspace/data/ov-v3/seg'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
f0 = np.load(os.path.join(DATA_DIR, 'frame.0.seg.npy'))

# %%
plt.imshow(color.label2rgb(f0))
# Out:
# /tmp/ipykernel_33457/755112018.py:1: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.
#   plt.imshow(color.label2rgb(f0))
